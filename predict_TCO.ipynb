# %%
from textblob.classifiers import NaiveBayesClassifier
from textblob import TextBlob
from collections import Counter
import math
import glob
import re
import time

start_time = time.time()
filename = "full_size_pickups"

def read_automobiles(filename):
    """ Read a list of automobiles.
    Args:
      filename: The name of the text file containing automobiles make model year.
    Returns:
      A list of automobile make model year
    """
    automobiles = []
    with open(filename) as f:
        lines = f.read().splitlines()
        for item in lines:
            automobiles.append(item)  
    return automobiles

autos = read_automobiles(filename+'.txt')
test = []
train = [('''I'm at 5000 miles and at 4400 miles I took the new truck I purchased in October 2013 in to the Ford Dealership for rust issues.
The inside (back side) of the chrome bumpers are showing corrosion, the air intake in the front bumper for the ecoboost models has an angled plate that is rusting and the factory painted (black) areas underneath are already showing rust.
The dealer contacted Ford after taking photos and Ford responded it's normal wear and tear, no action taken on it.
The running board is also starting to corrode where the driver mirrors drips down onto it due to the design.
in heavy rain the turbo misfires and the service engine light blinks and all power was lost.''', '50000-55000')]
cl = NaiveBayesClassifier(train)
training_percent = 0.8


for auto in autos:
    print "-------------------------------gethering test sample from "+auto+"--------------------------------"
    filelist = []

    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 5000 and float(line.split()[4])<10000:
                            price = "5000-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<15000:
                            price = "10000-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<20000:
                            price = "15000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<25000:
                            price = "20000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<30000:
                            price = "25000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<35000:
                            price = "30000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<40000:
                            price = "35000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<45000:
                            price = "40000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<50000:
                            price = "45000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<55000:
                            price = "50000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<60000:
                            price = "55000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<65000:
                            price = "60000-65000"
                        if float(line.split()[4]) >= 65000 and float(line.split()[4])<70000:
                            price = "65000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<75000:
                            price = "70000-75000"
                        if float(line.split()[4]) >= 75000 and float(line.split()[4])<80000:
                            price = "75000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<85000:
                            price = "80000-85000"
                        if float(line.split()[4]) >= 85000 and float(line.split()[4])<90000:
                            price = "85000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<95000:
                            price = "90000-95000"
                        if float(line.split()[4]) >= 95000 and float(line.split()[4])<100000:
                            price = "95000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                    
                        for i in range(train_set,len(reviews)):
                            test.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))

for auto in autos:
    filelist = []
    train = []
    train_percent = 0.8
    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 5000 and float(line.split()[4])<10000:
                            price = "5000-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<15000:
                            price = "10000-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<20000:
                            price = "15000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<25000:
                            price = "20000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<30000:
                            price = "25000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<35000:
                            price = "30000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<40000:
                            price = "35000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<45000:
                            price = "40000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<50000:
                            price = "45000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<55000:
                            price = "50000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<60000:
                            price = "55000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<65000:
                            price = "60000-65000"
                        if float(line.split()[4]) >= 65000 and float(line.split()[4])<70000:
                            price = "65000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<75000:
                            price = "70000-75000"
                        if float(line.split()[4]) >= 75000 and float(line.split()[4])<80000:
                            price = "75000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<85000:
                            price = "80000-85000"
                        if float(line.split()[4]) >= 85000 and float(line.split()[4])<90000:
                            price = "85000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<95000:
                            price = "90000-95000"
                        if float(line.split()[4]) >= 95000 and float(line.split()[4])<100000:
                            price = "95000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                        if train_set is 0:
                            for i in range(0,len(reviews)):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
                        else:
                            for i in range(0,train_set):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
    print "---------------------------------------------------feeding "+auto+" updateing-------------------------------------------"                      
    cl.update(train)
    # Compute accuracy
    print("Accuracy: {0}".format(cl.accuracy(test)))
 
    # Show 5 most informative features
    cl.show_informative_features(10)
    
print "\nRunning time is %s seconds"%(time.time()-start_time)
# Out:
# -------------------------------gethering test sample from Chevrolet Silverado-1500 2014--------------------------------
# -------------------------------gethering test sample from Ram 1500 2014--------------------------------
# -------------------------------gethering test sample from GMC Sierra-1500 2014--------------------------------
# -------------------------------gethering test sample from Ford F-150 2014--------------------------------
# -------------------------------gethering test sample from Toyota Tundra 2014--------------------------------
# -------------------------------gethering test sample from Nissan Titan 2014--------------------------------
# -------------------------------gethering test sample from Chevrolet Silverado-1500 2013--------------------------------
# -------------------------------gethering test sample from Ram 1500 2013--------------------------------
# -------------------------------gethering test sample from Ford F-150 2013--------------------------------
# -------------------------------gethering test sample from Nissan Titan 2013--------------------------------
# ---------------------------------------------------feeding Chevrolet Silverado-1500 2014 updateing-------------------------------------------
# Accuracy: 0.463414634146
# Most Informative Features
#          contains(thing) = True           40000- : 55000- =     12.1 : 1.0
#           contains(want) = True           40000- : 55000- =      8.7 : 1.0
#          contains(until) = True           45000- : 55000- =      8.7 : 1.0
#          contains(every) = True           40000- : 55000- =      8.7 : 1.0
#          contains(right) = True           40000- : 55000- =      8.7 : 1.0
#           contains(paid) = True           40000- : 55000- =      8.7 : 1.0
#            contains(hit) = True           40000- : 55000- =      8.7 : 1.0
#             contains(am) = True           50000- : 55000- =      8.7 : 1.0
#           contains(rode) = True           40000- : 55000- =      8.7 : 1.0
#          contains(light) = True           50000- : 55000- =      6.7 : 1.0
# ---------------------------------------------------feeding Ram 1500 2014 updateing-------------------------------------------
# Accuracy: 0.524390243902
# Most Informative Features
#              contains(i) = True           40000- : 55000- =     14.0 : 1.0
#          contains(thing) = True           40000- : 55000- =     14.0 : 1.0
#            contains(big) = True           60000- : 55000- =     12.5 : 1.0
#             contains(to) = False          60000- : 55000- =     12.5 : 1.0
#           contains(Have) = True           60000- : 55000- =     12.5 : 1.0
#         contains(towing) = True           60000- : 55000- =     12.5 : 1.0
#          contains(seems) = True           60000- : 55000- =     12.5 : 1.0
#           contains(high) = True           60000- : 55000- =     10.5 : 1.0
#           contains(want) = True           40000- : 55000- =     10.0 : 1.0
#          contains(until) = True           45000- : 55000- =     10.0 : 1.0
# ---------------------------------------------------feeding GMC Sierra-1500 2014 updateing-------------------------------------------
# Accuracy: 0.609756097561
# Most Informative Features
#            contains(guy) = True           40000- : 50000- =     13.5 : 1.0
#       contains(actually) = True           45000- : 50000- =     13.0 : 1.0
#           contains(snow) = True           60000- : 50000- =     12.0 : 1.0
#         contains(months) = True           15000- : 50000- =     12.0 : 1.0
#           contains(went) = True           60000- : 50000- =     12.0 : 1.0
#              contains(I) = False          15000- : 50000- =     12.0 : 1.0
#            contains(Not) = True           60000- : 50000- =     12.0 : 1.0
#      contains(corrosion) = True           15000- : 50000- =     12.0 : 1.0
#             contains(to) = False          60000- : 50000- =     12.0 : 1.0
#           contains(Have) = True           60000- : 50000- =     12.0 : 1.0
# ---------------------------------------------------feeding Ford F-150 2014 updateing-------------------------------------------
# Accuracy: 0.609756097561
# Most Informative Features
#              contains(I) = False          70000- : 50000- =     18.0 : 1.0
#          contains(Great) = True           70000- : 55000- =     17.5 : 1.0
#            contains(guy) = True           40000- : 50000- =     13.5 : 1.0
#       contains(actually) = True           45000- : 50000- =     13.0 : 1.0
#           contains(snow) = True           60000- : 50000- =     12.0 : 1.0
#         contains(months) = True           15000- : 50000- =     12.0 : 1.0
#           contains(went) = True           60000- : 50000- =     12.0 : 1.0
#            contains(Not) = True           60000- : 50000- =     12.0 : 1.0
#      contains(corrosion) = True           15000- : 50000- =     12.0 : 1.0
#             contains(to) = False          60000- : 50000- =     12.0 : 1.0
# ---------------------------------------------------feeding Toyota Tundra 2014 updateing-------------------------------------------
# Accuracy: 0.646341463415
# Most Informative Features
#          contains(Great) = True           70000- : 55000- =     21.5 : 1.0
#              contains(I) = False          70000- : 50000- =     19.0 : 1.0
#           contains(lane) = True           65000- : 55000- =     17.9 : 1.0
#        contains(highest) = True           65000- : 55000- =     17.9 : 1.0
#           contains(Good) = True           65000- : 55000- =     17.9 : 1.0
#          contains(front) = True           65000- : 50000- =     15.8 : 1.0
#       contains(switches) = True           65000- : 50000- =     15.8 : 1.0
#           contains(line) = True           65000- : 50000- =     15.8 : 1.0
#        contains(trailer) = True           65000- : 50000- =     15.8 : 1.0
#           contains(door) = True           65000- : 50000- =     15.8 : 1.0
# ---------------------------------------------------feeding Nissan Titan 2014 updateing-------------------------------------------
# Accuracy: 0.646341463415
# Most Informative Features
#          contains(Great) = True           70000- : 55000- =     21.5 : 1.0
#              contains(I) = False          70000- : 50000- =     19.0 : 1.0
#           contains(lane) = True           65000- : 55000- =     17.9 : 1.0
#        contains(highest) = True           65000- : 55000- =     17.9 : 1.0
#           contains(Good) = True           65000- : 55000- =     17.9 : 1.0
#          contains(front) = True           65000- : 50000- =     15.8 : 1.0
#       contains(switches) = True           65000- : 50000- =     15.8 : 1.0
#           contains(line) = True           65000- : 50000- =     15.8 : 1.0
#        contains(trailer) = True           65000- : 50000- =     15.8 : 1.0
#           contains(door) = True           65000- : 50000- =     15.8 : 1.0
# ---------------------------------------------------feeding Chevrolet Silverado-1500 2013 updateing-------------------------------------------
# Accuracy: 0.646341463415
# Most Informative Features
#          contains(Great) = True           70000- : 55000- =     22.0 : 1.0
#              contains(I) = False          70000- : 50000- =     19.5 : 1.0
#           contains(lane) = True           65000- : 55000- =     18.3 : 1.0
#        contains(highest) = True           65000- : 55000- =     18.3 : 1.0
#           contains(Good) = True           65000- : 55000- =     18.3 : 1.0
#          contains(front) = True           65000- : 50000- =     16.2 : 1.0
#       contains(switches) = True           65000- : 50000- =     16.2 : 1.0
#           contains(line) = True           65000- : 50000- =     16.2 : 1.0
#        contains(trailer) = True           65000- : 50000- =     16.2 : 1.0
#           contains(door) = True           65000- : 50000- =     16.2 : 1.0
# ---------------------------------------------------feeding Ram 1500 2013 updateing-------------------------------------------
# Accuracy: 0.719512195122
# Most Informative Features
#          contains(Great) = True           70000- : 55000- =     24.0 : 1.0
#            contains(fun) = True           70000- : 50000- =     20.5 : 1.0
#              contains(I) = False          70000- : 50000- =     20.5 : 1.0
#           contains(lane) = True           65000- : 55000- =     20.0 : 1.0
#        contains(highest) = True           65000- : 55000- =     20.0 : 1.0
#           contains(Good) = True           65000- : 55000- =     20.0 : 1.0
#            contains(add) = True           65000- : 55000- =     20.0 : 1.0
#        contains(missing) = True           65000- : 55000- =     20.0 : 1.0
#          contains(front) = True           65000- : 50000- =     17.1 : 1.0
#       contains(switches) = True           65000- : 50000- =     17.1 : 1.0
# ---------------------------------------------------feeding Ford F-150 2013 updateing-------------------------------------------
# Accuracy: 0.743902439024
# Most Informative Features
#          contains(Great) = True           70000- : 55000- =     25.0 : 1.0
#            contains(fun) = True           70000- : 50000- =     23.0 : 1.0
#              contains(I) = False          70000- : 50000- =     23.0 : 1.0
#           contains(lane) = True           65000- : 55000- =     16.7 : 1.0
#           contains(Good) = True           65000- : 55000- =     16.7 : 1.0
#            contains(add) = True           65000- : 55000- =     16.7 : 1.0
#        contains(highest) = True           65000- : 55000- =     16.7 : 1.0
#        contains(missing) = True           65000- : 55000- =     16.7 : 1.0
#         contains(having) = True           65000- : 50000- =     15.3 : 1.0
#       contains(switches) = True           65000- : 50000- =     15.3 : 1.0
# ---------------------------------------------------feeding Nissan Titan 2013 updateing-------------------------------------------
# Accuracy: 0.743902439024
# Most Informative Features
#          contains(Great) = True           70000- : 55000- =     25.0 : 1.0
#            contains(fun) = True           70000- : 50000- =     23.0 : 1.0
#              contains(I) = False          70000- : 50000- =     23.0 : 1.0
#           contains(lane) = True           65000- : 55000- =     16.7 : 1.0
#           contains(Good) = True           65000- : 55000- =     16.7 : 1.0
#            contains(add) = True           65000- : 55000- =     16.7 : 1.0
#        contains(highest) = True           65000- : 55000- =     16.7 : 1.0
#        contains(missing) = True           65000- : 55000- =     16.7 : 1.0
#         contains(having) = True           65000- : 50000- =     15.3 : 1.0
#       contains(switches) = True           65000- : 50000- =     15.3 : 1.0
#
# Running time is 353.596801996 seconds

# %%
from textblob.classifiers import NaiveBayesClassifier
from textblob import TextBlob
from collections import Counter
import math
import glob
import re
import time

start_time = time.time()
filename = "hybrid_cars"

def read_automobiles(filename):
    """ Read a list of automobiles.
    Args:
      filename: The name of the text file containing automobiles make model year.
    Returns:
      A list of automobile make model year
    """
    automobiles = []
    with open(filename) as f:
        lines = f.read().splitlines()
        for item in lines:
            automobiles.append(item)  
    return automobiles

autos = read_automobiles(filename+'.txt')
test = []
train = [('''I bought this car 6 weeks ago for an around the country trip.
So far I've put 9000 miles on the car and traveled from Atlanta through the north to Oregon, to South California, and back through the south.
2 weeks after I bought the car, Ford came out with their announcement....sorry...we meant 40 MPG on the road, not 47.
That was one of the reasons I had purchased this car.
But hey, going to get some money back in September, right?
Fuel milage has only once came near the 40 (new number) for the highway.
So far, I'm averaging around 36 mpg.
That has been disappointing.
But the other reasons I bought the car was for the comfort and quiet on on that it delivers!''', '30000-40000')]
cl = NaiveBayesClassifier(train)
training_percent = 0.8


for auto in autos:
    print "-------------------------------gethering test sample from "+auto+"--------------------------------"
    filelist = []

    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 5000 and float(line.split()[4])<10000:
                            price = "5000-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<15000:
                            price = "10000-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<20000:
                            price = "15000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<25000:
                            price = "20000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<30000:
                            price = "25000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<35000:
                            price = "30000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<40000:
                            price = "35000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<45000:
                            price = "40000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<50000:
                            price = "45000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<55000:
                            price = "50000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<60000:
                            price = "55000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<65000:
                            price = "60000-65000"
                        if float(line.split()[4]) >= 65000 and float(line.split()[4])<70000:
                            price = "65000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<75000:
                            price = "70000-75000"
                        if float(line.split()[4]) >= 75000 and float(line.split()[4])<80000:
                            price = "75000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<85000:
                            price = "80000-85000"
                        if float(line.split()[4]) >= 85000 and float(line.split()[4])<90000:
                            price = "85000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<95000:
                            price = "90000-95000"
                        if float(line.split()[4]) >= 95000 and float(line.split()[4])<100000:
                            price = "95000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                    
                        for i in range(train_set,len(reviews)):
                            test.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))

for auto in autos:
    filelist = []
    train = []
    train_percent = 0.8
    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 5000 and float(line.split()[4])<10000:
                            price = "5000-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<15000:
                            price = "10000-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<20000:
                            price = "15000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<25000:
                            price = "20000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<30000:
                            price = "25000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<35000:
                            price = "30000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<40000:
                            price = "35000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<45000:
                            price = "40000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<50000:
                            price = "45000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<55000:
                            price = "50000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<60000:
                            price = "55000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<65000:
                            price = "60000-65000"
                        if float(line.split()[4]) >= 65000 and float(line.split()[4])<70000:
                            price = "65000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<75000:
                            price = "70000-75000"
                        if float(line.split()[4]) >= 75000 and float(line.split()[4])<80000:
                            price = "75000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<85000:
                            price = "80000-85000"
                        if float(line.split()[4]) >= 85000 and float(line.split()[4])<90000:
                            price = "85000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<95000:
                            price = "90000-95000"
                        if float(line.split()[4]) >= 95000 and float(line.split()[4])<100000:
                            price = "95000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                        if train_set is 0:
                            for i in range(0,len(reviews)):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
                        else:
                            for i in range(0,train_set):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
    print "---------------------------------------------------feeding "+auto+" updateing-------------------------------------------"                      
    cl.update(train)
    # Compute accuracy
    print("Accuracy: {0}".format(cl.accuracy(test)))
 
    # Show 5 most informative features
    cl.show_informative_features(10)
    
print "\nRunning time is %s seconds"%(time.time()-start_time)
# Out:
# -------------------------------gethering test sample from Toyota Camry-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Honda Accord-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Hyundai Sonata-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Toyota Avalon-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Toyota Prius 2014--------------------------------
# -------------------------------gethering test sample from Nissan Leaf 2014--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Energi 2014--------------------------------
# -------------------------------gethering test sample from Kia Optima-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Honda Civic-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Honda CR-Z 2014--------------------------------
# -------------------------------gethering test sample from Honda Insight 2014--------------------------------
# -------------------------------gethering test sample from Toyota Prius-Plug-In 2014--------------------------------
# -------------------------------gethering test sample from Toyota Camry-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Honda Accord-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Hyundai Sonata-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Toyota Avalon-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Ford C-Max-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Toyota Prius 2013--------------------------------
# -------------------------------gethering test sample from Nissan Leaf 2013--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Energi 2013--------------------------------
# -------------------------------gethering test sample from Kia Optima-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Honda Civic-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Honda CR-Z 2013--------------------------------
# -------------------------------gethering test sample from Honda Insight 2013--------------------------------
# -------------------------------gethering test sample from Toyota Prius-Plug-In 2013--------------------------------
# -------------------------------gethering test sample from Toyota Prius-c 2013--------------------------------
# -------------------------------gethering test sample from Chevrolet Volt 2013--------------------------------
# ---------------------------------------------------feeding Toyota Camry-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.258620689655
# Most Informative Features
#          contains(until) = False          35000- : 40000- =      1.5 : 1.0
#         contains(fourth) = False          35000- : 40000- =      1.5 : 1.0
#     contains(Everything) = False          35000- : 40000- =      1.5 : 1.0
#           contains(hard) = False          35000- : 40000- =      1.5 : 1.0
#           contains(make) = False          35000- : 40000- =      1.5 : 1.0
#          contains(Seats) = False          35000- : 40000- =      1.5 : 1.0
#     contains(electronic) = False          35000- : 40000- =      1.5 : 1.0
#           contains(well) = False          35000- : 40000- =      1.5 : 1.0
#        contains(pockets) = False          35000- : 40000- =      1.5 : 1.0
#          contains(cushy) = False          35000- : 40000- =      1.5 : 1.0
# ---------------------------------------------------feeding Ford Fusion-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.275862068966
# Most Informative Features
#           contains(been) = True           35000- : 40000- =      6.4 : 1.0
#          contains(other) = True           35000- : 40000- =      6.4 : 1.0
#              contains(I) = False          45000- : 40000- =      6.1 : 1.0
#            contains(for) = False          45000- : 40000- =      6.1 : 1.0
#           contains(some) = True           35000- : 40000- =      4.6 : 1.0
#          contains(money) = True           35000- : 40000- =      4.6 : 1.0
#       contains(traveled) = True           35000- : 40000- =      4.6 : 1.0
#        contains(comfort) = True           35000- : 40000- =      4.6 : 1.0
#            contains(get) = True           35000- : 40000- =      4.6 : 1.0
#      contains(averaging) = True           35000- : 40000- =      4.6 : 1.0
# ---------------------------------------------------feeding Honda Accord-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.275862068966
# Most Informative Features
#           contains(been) = True           35000- : 40000- =      6.2 : 1.0
#           contains(some) = True           35000- : 40000- =      6.2 : 1.0
#           contains(once) = True           35000- : 40000- =      6.2 : 1.0
#          contains(other) = True           35000- : 40000- =      6.2 : 1.0
#        contains(battery) = True           45000- : 40000- =      5.3 : 1.0
#            contains(new) = True           35000- : 40000- =      4.4 : 1.0
#       contains(traveled) = True           35000- : 40000- =      4.4 : 1.0
#              contains(2) = True           35000- : 40000- =      4.4 : 1.0
#        contains(comfort) = True           35000- : 40000- =      4.4 : 1.0
#            contains(But) = True           35000- : 40000- =      4.4 : 1.0
# ---------------------------------------------------feeding Hyundai Sonata-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.275862068966
# Most Informative Features
#           contains(some) = True           35000- : 40000- =      6.6 : 1.0
#           contains(been) = True           35000- : 40000- =      6.6 : 1.0
#           contains(once) = True           35000- : 40000- =      6.6 : 1.0
#          contains(other) = True           35000- : 40000- =      6.6 : 1.0
#        contains(battery) = True           45000- : 40000- =      5.7 : 1.0
#            contains(new) = True           35000- : 40000- =      4.7 : 1.0
#           contains(back) = True           35000- : 40000- =      4.7 : 1.0
#       contains(traveled) = True           35000- : 40000- =      4.7 : 1.0
#              contains(2) = True           35000- : 40000- =      4.7 : 1.0
#        contains(comfort) = True           35000- : 40000- =      4.7 : 1.0
# ---------------------------------------------------feeding Toyota Avalon-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.275862068966
# Most Informative Features
#           contains(ride) = True           50000- : 40000- =      9.4 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      7.2 : 1.0
#           contains(some) = True           35000- : 40000- =      6.6 : 1.0
#           contains(been) = True           35000- : 40000- =      6.6 : 1.0
#           contains(once) = True           35000- : 40000- =      6.6 : 1.0
#          contains(other) = True           35000- : 40000- =      6.6 : 1.0
#          contains(quite) = True           50000- : 40000- =      5.7 : 1.0
#          contains(There) = True           50000- : 40000- =      5.7 : 1.0
#            contains(new) = True           50000- : 40000- =      5.7 : 1.0
#          contains(close) = True           50000- : 40000- =      5.7 : 1.0
# ---------------------------------------------------feeding Toyota Prius 2014 updateing-------------------------------------------
# Accuracy: 0.293103448276
# Most Informative Features
#           contains(ride) = True           50000- : 40000- =      9.4 : 1.0
#            contains(new) = True           30000- : 40000- =      8.5 : 1.0
#              contains(I) = False          30000- : 40000- =      8.5 : 1.0
#          contains(years) = True           30000- : 40000- =      8.5 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      7.2 : 1.0
#             contains(is) = False          30000- : 45000- =      6.5 : 1.0
#              contains(a) = False          30000- : 45000- =      6.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      5.7 : 1.0
#          contains(quite) = True           50000- : 40000- =      5.7 : 1.0
#          contains(close) = True           50000- : 40000- =      5.7 : 1.0
# ---------------------------------------------------feeding Nissan Leaf 2014 updateing-------------------------------------------
# Accuracy: 0.293103448276
# Most Informative Features
#           contains(ride) = True           50000- : 40000- =      9.4 : 1.0
#            contains(new) = True           30000- : 40000- =      8.5 : 1.0
#              contains(I) = False          30000- : 40000- =      8.5 : 1.0
#          contains(years) = True           30000- : 40000- =      8.5 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      7.2 : 1.0
#             contains(is) = False          30000- : 45000- =      6.5 : 1.0
#              contains(a) = False          30000- : 45000- =      6.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      5.7 : 1.0
#          contains(quite) = True           50000- : 40000- =      5.7 : 1.0
#          contains(close) = True           50000- : 40000- =      5.7 : 1.0
# ---------------------------------------------------feeding Ford Fusion-Energi 2014 updateing-------------------------------------------
# Accuracy: 0.310344827586
# Most Informative Features
#            contains(new) = True           30000- : 40000- =      9.0 : 1.0
#             contains(25) = True           30000- : 40000- =      9.0 : 1.0
#          contains(years) = True           30000- : 40000- =      9.0 : 1.0
#              contains(I) = False          30000- : 40000- =      9.0 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#              contains(a) = False          30000- : 45000- =      7.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      6.0 : 1.0
#          contains(quite) = True           50000- : 40000- =      6.0 : 1.0
#           contains(ride) = True           50000- : 40000- =      6.0 : 1.0
# ---------------------------------------------------feeding Kia Optima-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.310344827586
# Most Informative Features
#            contains(new) = True           30000- : 40000- =      9.0 : 1.0
#             contains(25) = True           30000- : 40000- =      9.0 : 1.0
#          contains(years) = True           30000- : 40000- =      9.0 : 1.0
#              contains(I) = False          30000- : 40000- =      9.0 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#              contains(a) = False          30000- : 45000- =      7.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      6.0 : 1.0
#          contains(quite) = True           50000- : 40000- =      6.0 : 1.0
#           contains(ride) = True           50000- : 40000- =      6.0 : 1.0
# ---------------------------------------------------feeding Honda Civic-Hybrid 2014 updateing-------------------------------------------
# Accuracy: 0.310344827586
# Most Informative Features
#            contains(new) = True           30000- : 40000- =      9.0 : 1.0
#             contains(25) = True           30000- : 40000- =      9.0 : 1.0
#          contains(years) = True           30000- : 40000- =      9.0 : 1.0
#              contains(I) = False          30000- : 40000- =      9.0 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#              contains(a) = False          30000- : 45000- =      7.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      6.0 : 1.0
#          contains(quite) = True           50000- : 40000- =      6.0 : 1.0
#           contains(ride) = True           50000- : 40000- =      6.0 : 1.0
# ---------------------------------------------------feeding Honda CR-Z 2014 updateing-------------------------------------------
# Accuracy: 0.327586206897
# Most Informative Features
#            contains(new) = True           30000- : 40000- =      9.0 : 1.0
#             contains(25) = True           30000- : 40000- =      9.0 : 1.0
#          contains(years) = True           30000- : 40000- =      9.0 : 1.0
#              contains(I) = False          30000- : 40000- =      9.0 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#              contains(a) = False          30000- : 45000- =      7.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      6.0 : 1.0
#          contains(quite) = True           50000- : 40000- =      6.0 : 1.0
#           contains(ride) = True           50000- : 40000- =      6.0 : 1.0
# ---------------------------------------------------feeding Honda Insight 2014 updateing-------------------------------------------
# Accuracy: 0.327586206897
# Most Informative Features
#            contains(new) = True           30000- : 40000- =      9.0 : 1.0
#             contains(25) = True           30000- : 40000- =      9.0 : 1.0
#          contains(years) = True           30000- : 40000- =      9.0 : 1.0
#              contains(I) = False          30000- : 40000- =      9.0 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#              contains(a) = False          30000- : 45000- =      7.5 : 1.0
#           contains(feel) = True           50000- : 40000- =      6.0 : 1.0
#          contains(quite) = True           50000- : 40000- =      6.0 : 1.0
#           contains(ride) = True           50000- : 40000- =      6.0 : 1.0
# ---------------------------------------------------feeding Toyota Prius-Plug-In 2014 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#            contains(new) = True           30000- : 40000- =      9.0 : 1.0
#             contains(25) = True           30000- : 40000- =      9.0 : 1.0
#              contains(I) = False          30000- : 40000- =      9.0 : 1.0
#          contains(years) = True           30000- : 40000- =      9.0 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#              contains(a) = False          30000- : 45000- =      7.5 : 1.0
#          contains(other) = True           35000- : 40000- =      6.6 : 1.0
#           contains(feel) = True           50000- : 40000- =      6.0 : 1.0
#          contains(quite) = True           50000- : 40000- =      6.0 : 1.0
# ---------------------------------------------------feeding Toyota Camry-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.327586206897
# Most Informative Features
#             contains(25) = True           30000- : 40000- =     10.5 : 1.0
#              contains(a) = False          30000- : 40000- =     10.5 : 1.0
#            contains(the) = False          30000- : 40000- =     10.5 : 1.0
#          contains(years) = True           30000- : 40000- =     10.5 : 1.0
#         contains(Toyota) = True           50000- : 45000- =      8.3 : 1.0
#             contains(is) = False          30000- : 45000- =      7.5 : 1.0
#          contains(quite) = True           50000- : 40000- =      7.0 : 1.0
#           contains(ride) = True           50000- : 40000- =      7.0 : 1.0
#         contains(normal) = True           50000- : 40000- =      7.0 : 1.0
#          contains(close) = True           50000- : 40000- =      7.0 : 1.0
# ---------------------------------------------------feeding Ford Fusion-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.327586206897
# Most Informative Features
#             contains(25) = True           30000- : 40000- =     14.5 : 1.0
#            contains(the) = False          30000- : 40000- =     14.5 : 1.0
#      contains(impressed) = True           30000- : 40000- =     14.5 : 1.0
#          contains(years) = True           30000- : 40000- =     14.5 : 1.0
#         contains(Toyota) = True           50000- : 45000- =     10.6 : 1.0
#         contains(normal) = True           50000- : 40000- =      9.7 : 1.0
#           contains(nice) = True           50000- : 40000- =      9.7 : 1.0
#          contains(close) = True           50000- : 40000- =      9.7 : 1.0
#       contains(improved) = True           50000- : 40000- =      9.7 : 1.0
#           contains(good) = True           50000- : 40000- =      9.7 : 1.0
# ---------------------------------------------------feeding Honda Accord-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.327586206897
# Most Informative Features
#             contains(25) = True           30000- : 40000- =     14.5 : 1.0
#            contains(the) = False          30000- : 40000- =     14.5 : 1.0
#      contains(impressed) = True           30000- : 40000- =     14.5 : 1.0
#          contains(years) = True           30000- : 40000- =     14.5 : 1.0
#         contains(Toyota) = True           50000- : 45000- =     10.6 : 1.0
#         contains(normal) = True           50000- : 40000- =      9.7 : 1.0
#           contains(nice) = True           50000- : 40000- =      9.7 : 1.0
#          contains(close) = True           50000- : 40000- =      9.7 : 1.0
#       contains(improved) = True           50000- : 40000- =      9.7 : 1.0
#           contains(good) = True           50000- : 40000- =      9.7 : 1.0
# ---------------------------------------------------feeding Hyundai Sonata-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.379310344828
# Most Informative Features
#             contains(25) = True           30000- : 40000- =     14.5 : 1.0
#            contains(the) = False          30000- : 40000- =     14.5 : 1.0
#      contains(impressed) = True           30000- : 40000- =     14.5 : 1.0
#          contains(years) = True           30000- : 40000- =     14.5 : 1.0
#           contains(test) = True           50000- : 45000- =     13.3 : 1.0
#            contains(and) = False          30000- : 45000- =     12.0 : 1.0
#         contains(normal) = True           50000- : 40000- =      9.7 : 1.0
#         contains(repair) = True           50000- : 40000- =      9.7 : 1.0
#         contains(Toyota) = True           50000- : 40000- =      9.7 : 1.0
#           contains(nice) = True           50000- : 40000- =      9.7 : 1.0
# ---------------------------------------------------feeding Toyota Avalon-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.396551724138
# Most Informative Features
#             contains(25) = True           30000- : 40000- =     20.5 : 1.0
#            contains(the) = False          30000- : 40000- =     20.5 : 1.0
#      contains(impressed) = True           30000- : 40000- =     20.5 : 1.0
#           contains(test) = True           50000- : 45000- =     17.8 : 1.0
#            contains(and) = False          30000- : 45000- =     16.0 : 1.0
#          contains(years) = True           30000- : 45000- =     16.0 : 1.0
#           contains(fuel) = True           50000- : 40000- =     13.7 : 1.0
#         contains(normal) = True           50000- : 40000- =     13.7 : 1.0
#         contains(repair) = True           50000- : 40000- =     13.7 : 1.0
#       contains(improved) = True           50000- : 40000- =     13.7 : 1.0
# ---------------------------------------------------feeding Ford C-Max-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#             contains(25) = True           30000- : 40000- =     24.5 : 1.0
#            contains(the) = False          30000- : 40000- =     24.5 : 1.0
#           contains(test) = True           50000- : 45000- =     17.8 : 1.0
#           contains(fuel) = True           50000- : 40000- =     16.3 : 1.0
#         contains(normal) = True           50000- : 40000- =     16.3 : 1.0
#         contains(repair) = True           50000- : 40000- =     16.3 : 1.0
#       contains(improved) = True           50000- : 40000- =     16.3 : 1.0
#          contains(least) = True           50000- : 40000- =     16.3 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     16.3 : 1.0
#          contains(Every) = True           50000- : 40000- =     16.3 : 1.0
# ---------------------------------------------------feeding Toyota Prius 2013 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#           contains(test) = True           50000- : 45000- =     17.8 : 1.0
#           contains(fuel) = True           50000- : 40000- =     16.3 : 1.0
#         contains(repair) = True           50000- : 40000- =     16.3 : 1.0
#       contains(improved) = True           50000- : 40000- =     16.3 : 1.0
#          contains(least) = True           50000- : 40000- =     16.3 : 1.0
#          contains(Prius) = True           30000- : 40000- =     16.3 : 1.0
#          contains(Every) = True           50000- : 40000- =     16.3 : 1.0
#         contains(normal) = True           50000- : 40000- =     16.3 : 1.0
#             contains(us) = True           50000- : 40000- =     16.3 : 1.0
#          contains(stiff) = True           50000- : 40000- =     16.3 : 1.0
# ---------------------------------------------------feeding Nissan Leaf 2013 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     18.4 : 1.0
#           contains(test) = True           50000- : 45000- =     17.8 : 1.0
#        contains(through) = True           50000- : 40000- =     16.3 : 1.0
#            contains(yet) = True           50000- : 40000- =     16.3 : 1.0
#       contains(improved) = True           50000- : 40000- =     16.3 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     16.3 : 1.0
#          contains(Every) = True           50000- : 40000- =     16.3 : 1.0
#            contains(buy) = True           50000- : 40000- =     16.3 : 1.0
#         contains(repair) = True           50000- : 40000- =     16.3 : 1.0
#          contains(least) = True           50000- : 40000- =     16.3 : 1.0
# ---------------------------------------------------feeding Ford Fusion-Energi 2013 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#         contains(repair) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Kia Optima-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#         contains(repair) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Honda Civic-Hybrid 2013 updateing-------------------------------------------
# Accuracy: 0.344827586207
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#         contains(repair) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Honda CR-Z 2013 updateing-------------------------------------------
# Accuracy: 0.362068965517
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#         contains(repair) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Honda Insight 2013 updateing-------------------------------------------
# Accuracy: 0.379310344828
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#         contains(repair) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Toyota Prius-Plug-In 2013 updateing-------------------------------------------
# Accuracy: 0.379310344828
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#         contains(repair) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Toyota Prius-c 2013 updateing-------------------------------------------
# Accuracy: 0.396551724138
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
#         contains(longer) = True           50000- : 40000- =     17.0 : 1.0
# ---------------------------------------------------feeding Chevrolet Volt 2013 updateing-------------------------------------------
# Accuracy: 0.431034482759
# Most Informative Features
#         contains(charge) = True           20000- : 40000- =     19.1 : 1.0
#           contains(test) = True           50000- : 45000- =     18.3 : 1.0
#        contains(through) = True           50000- : 40000- =     17.0 : 1.0
#            contains(yet) = True           50000- : 40000- =     17.0 : 1.0
#       contains(improved) = True           50000- : 40000- =     17.0 : 1.0
#      contains(luxurious) = True           50000- : 40000- =     17.0 : 1.0
#          contains(Every) = True           50000- : 40000- =     17.0 : 1.0
#            contains(buy) = True           50000- : 40000- =     17.0 : 1.0
#          contains(least) = True           50000- : 40000- =     17.0 : 1.0
#         contains(longer) = True           50000- : 40000- =     17.0 : 1.0
#
# Running time is 653.456357956 seconds

# %%
from textblob.classifiers import NaiveBayesClassifier
from textblob import TextBlob
from collections import Counter
import math
import glob
import re
import time

start_time = time.time()
filename = "midsize_cars"

def read_automobiles(filename):
    """ Read a list of automobiles.
    Args:
      filename: The name of the text file containing automobiles make model year.
    Returns:
      A list of automobile make model year
    """
    automobiles = []
    with open(filename) as f:
        lines = f.read().splitlines()
        for item in lines:
            automobiles.append(item)  
    return automobiles

autos = read_automobiles(filename+'.txt')
test = []
train = [('''I was looking or a larger car yet didn't want a sit up high SUV. I liked these when they first came out yet was hessitant so waited a few years and I am glad I did. It glides real smooth when driving it has great handling and turning radius. Not hard to park. The eco boost is awesome. It gets up and goes when you hit the peddle. Great for long hauls and short hauls. Highway and back roads with all the curves. I have over 3,000 miles on it and can't complain. Teenagers and friends fit in fine. can carry 4 dogs 4 adults and some with no problem. If you want a minivan look at this first. Has all wheel drive too. ''', '60000-65000')]
cl = NaiveBayesClassifier(train)
training_percent = 0.8


for auto in autos:
    print "-------------------------------gethering test sample from "+auto+"--------------------------------"
    filelist = []

    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 5000 and float(line.split()[4])<10000:
                            price = "5000-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<15000:
                            price = "10000-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<20000:
                            price = "15000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<25000:
                            price = "20000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<30000:
                            price = "25000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<35000:
                            price = "30000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<40000:
                            price = "35000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<45000:
                            price = "40000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<50000:
                            price = "45000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<55000:
                            price = "50000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<60000:
                            price = "55000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<65000:
                            price = "60000-65000"
                        if float(line.split()[4]) >= 65000 and float(line.split()[4])<70000:
                            price = "65000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<75000:
                            price = "70000-75000"
                        if float(line.split()[4]) >= 75000 and float(line.split()[4])<80000:
                            price = "75000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<85000:
                            price = "80000-85000"
                        if float(line.split()[4]) >= 85000 and float(line.split()[4])<90000:
                            price = "85000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<95000:
                            price = "90000-95000"
                        if float(line.split()[4]) >= 95000 and float(line.split()[4])<100000:
                            price = "95000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                    
                        for i in range(train_set,len(reviews)):
                            test.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))

for auto in autos:
    filelist = []
    train = []
    train_percent = 0.8
    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 5000 and float(line.split()[4])<10000:
                            price = "5000-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<15000:
                            price = "10000-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<20000:
                            price = "15000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<25000:
                            price = "20000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<30000:
                            price = "25000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<35000:
                            price = "30000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<40000:
                            price = "35000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<45000:
                            price = "40000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<50000:
                            price = "45000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<55000:
                            price = "50000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<60000:
                            price = "55000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<65000:
                            price = "60000-65000"
                        if float(line.split()[4]) >= 65000 and float(line.split()[4])<70000:
                            price = "65000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<75000:
                            price = "70000-75000"
                        if float(line.split()[4]) >= 75000 and float(line.split()[4])<80000:
                            price = "75000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<85000:
                            price = "80000-85000"
                        if float(line.split()[4]) >= 85000 and float(line.split()[4])<90000:
                            price = "85000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<95000:
                            price = "90000-95000"
                        if float(line.split()[4]) >= 95000 and float(line.split()[4])<100000:
                            price = "95000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                        if train_set is 0:
                            for i in range(0,len(reviews)):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
                        else:
                            for i in range(0,train_set):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
    print "---------------------------------------------------feeding "+auto+" updateing-------------------------------------------"                      
    cl.update(train)
    # Compute accuracy
    print("Accuracy: {0}".format(cl.accuracy(test)))
 
    # Show 5 most informative features
    cl.show_informative_features(10)
    
print "\nRunning time is %s seconds"%(time.time()-start_time)
# Out:
# -------------------------------gethering test sample from Toyota Camry 2014--------------------------------
# -------------------------------gethering test sample from Kia Optima 2014--------------------------------
# -------------------------------gethering test sample from Volkswagen Passat 2014--------------------------------
# -------------------------------gethering test sample from Hyundai Sonata 2014--------------------------------
# -------------------------------gethering test sample from Toyota Camry-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Honda Accord-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Honda Accord 2014--------------------------------
# -------------------------------gethering test sample from Subaru Legacy 2014--------------------------------
# -------------------------------gethering test sample from Ford Fusion 2014--------------------------------
# -------------------------------gethering test sample from Nissan Altima 2014--------------------------------
# -------------------------------gethering test sample from Mazda Mazda6 2014--------------------------------
# -------------------------------gethering test sample from Hyundai Sonata-Hybrid 2014--------------------------------
# -------------------------------gethering test sample from Chevrolet Malibu 2014--------------------------------
# -------------------------------gethering test sample from Dodge Avenger 2014--------------------------------
# -------------------------------gethering test sample from Hyundai Sonata 2013--------------------------------
# -------------------------------gethering test sample from Toyota Camry-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Toyota Camry 2013--------------------------------
# -------------------------------gethering test sample from Honda Accord 2013--------------------------------
# -------------------------------gethering test sample from Subaru Legacy 2013--------------------------------
# -------------------------------gethering test sample from Chrysler 200 2013--------------------------------
# -------------------------------gethering test sample from Ford Fusion 2013--------------------------------
# -------------------------------gethering test sample from Nissan Altima 2013--------------------------------
# -------------------------------gethering test sample from Mazda Mazda6 2013--------------------------------
# -------------------------------gethering test sample from Hyundai Sonata-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Kia Optima 2013--------------------------------
# -------------------------------gethering test sample from Chevrolet Malibu 2013--------------------------------
# -------------------------------gethering test sample from Volkswagen Passat 2013--------------------------------
# -------------------------------gethering test sample from Ford Fusion-Energi 2013--------------------------------
# -------------------------------gethering test sample from Kia Optima-Hybrid 2013--------------------------------
# -------------------------------gethering test sample from Toyota Prius-Plug-In 2013--------------------------------
# -------------------------------gethering test sample from Dodge Avenger 2013--------------------------------
# ---------------------------------------------------feeding Toyota Camry 2014 updateing-------------------------------------------
# Accuracy: 0.242424242424
# Most Informative Features
#          contains(years) = True           60000- : 35000- =      4.5 : 1.0
#           contains(they) = True           60000- : 35000- =      4.5 : 1.0
#            contains(all) = True           60000- : 35000- =      4.5 : 1.0
#             contains(It) = True           60000- : 35000- =      4.5 : 1.0
#           contains(some) = True           60000- : 35000- =      4.5 : 1.0
#              contains(4) = True           60000- : 35000- =      4.5 : 1.0
#           contains(high) = True           60000- : 35000- =      4.5 : 1.0
#             contains(or) = True           60000- : 35000- =      4.5 : 1.0
#          contains(Great) = True           60000- : 35000- =      4.5 : 1.0
#          contains(liked) = True           60000- : 35000- =      4.5 : 1.0
# ---------------------------------------------------feeding Kia Optima 2014 updateing-------------------------------------------
# Accuracy: 0.246753246753
# Most Informative Features
#         contains(around) = True           50000- : 35000- =      7.5 : 1.0
#           contains(fuel) = True           50000- : 35000- =      7.5 : 1.0
#             contains(It) = True           60000- : 35000- =      7.5 : 1.0
#           contains(some) = True           60000- : 35000- =      7.5 : 1.0
#          contains(liked) = True           60000- : 35000- =      7.5 : 1.0
#          contains(value) = True           45000- : 35000- =      7.5 : 1.0
#           contains(Audi) = True           45000- : 35000- =      7.5 : 1.0
#             contains(or) = True           60000- : 35000- =      7.5 : 1.0
#           contains(more) = True           45000- : 35000- =      7.5 : 1.0
#            contains(Kia) = True           50000- : 35000- =      7.5 : 1.0
# ---------------------------------------------------feeding Volkswagen Passat 2014 updateing-------------------------------------------
# Accuracy: 0.264069264069
# Most Informative Features
#        contains(looking) = True           60000- : 10000- =      7.5 : 1.0
#           contains(some) = True           60000- : 35000- =      7.5 : 1.0
#          contains(Great) = True           60000- : 10000- =      7.5 : 1.0
#              contains(4) = True           60000- : 10000- =      7.5 : 1.0
#           contains(hard) = True           60000- : 10000- =      7.5 : 1.0
#             contains(or) = True           60000- : 35000- =      7.5 : 1.0
#             contains(ca) = True           60000- : 10000- =      7.5 : 1.0
#         contains(smooth) = True           60000- : 35000- =      7.5 : 1.0
#            contains(all) = True           60000- : 10000- =      7.5 : 1.0
#       contains(handling) = True           60000- : 10000- =      7.5 : 1.0
# ---------------------------------------------------feeding Hyundai Sonata 2014 updateing-------------------------------------------
# Accuracy: 0.333333333333

# %%
from textblob.classifiers import NaiveBayesClassifier
from textblob import TextBlob
from collections import Counter
import math
import glob
import re
import time

start_time = time.time()
filename = "full_size_pickups"

def read_automobiles(filename):
    """ Read a list of automobiles.
    Args:
      filename: The name of the text file containing automobiles make model year.
    Returns:
      A list of automobile make model year
    """
    automobiles = []
    with open(filename) as f:
        lines = f.read().splitlines()
        for item in lines:
            automobiles.append(item)  
    return automobiles

autos = read_automobiles(filename+'.txt')
test = []
train = [('''I'm at 5000 miles and at 4400 miles I took the new truck I purchased in October 2013 in to the Ford Dealership for rust issues.
The inside (back side) of the chrome bumpers are showing corrosion, the air intake in the front bumper for the ecoboost models has an angled plate that is rusting and the factory painted (black) areas underneath are already showing rust.
The dealer contacted Ford after taking photos and Ford responded it's normal wear and tear, no action taken on it.
The running board is also starting to corrode where the driver mirrors drips down onto it due to the design.
in heavy rain the turbo misfires and the service engine light blinks and all power was lost.''', '50000-60000')]
cl = NaiveBayesClassifier(train)
training_percent = 0.8


for auto in autos:
    print "-------------------------------gethering test sample from "+auto+"--------------------------------"
    filelist = []

    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 0 and float(line.split()[4])<10000:
                            price = "0-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<20000:
                            price = "10000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<30000:
                            price = "20000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<40000:
                            price = "30000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<50000:
                            price = "40000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<60000:
                            price = "50000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<70000:
                            price = "60000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<80000:
                            price = "70000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<90000:
                            price = "80000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<100000:
                            price = "90000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                    
                        for i in range(train_set,len(reviews)):
                            test.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))

for auto in autos:
    filelist = []
    train = []
    train_percent = 0.8
    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        if float(line.split()[4]) >= 0 and float(line.split()[4])<10000:
                            price = "0-10000"
                        if float(line.split()[4]) >= 10000 and float(line.split()[4])<20000:
                            price = "10000-20000"
                        if float(line.split()[4]) >= 20000 and float(line.split()[4])<30000:
                            price = "20000-30000"
                        if float(line.split()[4]) >= 30000 and float(line.split()[4])<40000:
                            price = "30000-40000"
                        if float(line.split()[4]) >= 40000 and float(line.split()[4])<50000:
                            price = "40000-50000"
                        if float(line.split()[4]) >= 50000 and float(line.split()[4])<60000:
                            price = "50000-60000"
                        if float(line.split()[4]) >= 60000 and float(line.split()[4])<70000:
                            price = "60000-70000"
                        if float(line.split()[4]) >= 70000 and float(line.split()[4])<80000:
                            price = "70000-80000"
                        if float(line.split()[4]) >= 80000 and float(line.split()[4])<90000:
                            price = "80000-90000"
                        if float(line.split()[4]) >= 90000 and float(line.split()[4])<100000:
                            price = "90000-100000"
                        if float(line.split()[4]) >= 100000:
                            price = ">100000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                        if train_set is 0:
                            for i in range(0,len(reviews)):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
                        else:
                            for i in range(0,train_set):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
    print "---------------------------------------------------feeding "+auto+" updateing-------------------------------------------"                      
    cl.update(train)
    # Compute accuracy
    print("Accuracy: {0}".format(cl.accuracy(test)))
 
    # Show 5 most informative features
    cl.show_informative_features(10)
    
print "\nRunning time is %s seconds"%(time.time()-start_time)
# Out:
# -------------------------------gethering test sample from Chevrolet Silverado-1500 2014--------------------------------
# -------------------------------gethering test sample from Ram 1500 2014--------------------------------
# -------------------------------gethering test sample from GMC Sierra-1500 2014--------------------------------
# -------------------------------gethering test sample from Ford F-150 2014--------------------------------
# -------------------------------gethering test sample from Toyota Tundra 2014--------------------------------
# -------------------------------gethering test sample from Nissan Titan 2014--------------------------------
# -------------------------------gethering test sample from Chevrolet Silverado-1500 2013--------------------------------
# -------------------------------gethering test sample from Ram 1500 2013--------------------------------
# -------------------------------gethering test sample from Ford F-150 2013--------------------------------
# -------------------------------gethering test sample from Nissan Titan 2013--------------------------------
# ---------------------------------------------------feeding Chevrolet Silverado-1500 2014 updateing-------------------------------------------
# Accuracy: 0.707317073171
# Most Informative Features
#          contains(until) = True           40000- : 50000- =      7.8 : 1.0
#          contains(thing) = True           40000- : 50000- =      6.1 : 1.0
#            contains(200) = True           40000- : 50000- =      6.1 : 1.0
#     contains(everything) = True           40000- : 50000- =      4.7 : 1.0
#            contains(for) = False          50000- : 40000- =      4.5 : 1.0
#            contains(how) = True           40000- : 50000- =      4.4 : 1.0
#            contains(put) = True           40000- : 50000- =      4.4 : 1.0
#          contains(right) = True           40000- : 50000- =      4.4 : 1.0
#      contains(pre-owned) = True           40000- : 50000- =      4.4 : 1.0
#            contains(way) = True           40000- : 50000- =      4.4 : 1.0
# ---------------------------------------------------feeding Ram 1500 2014 updateing-------------------------------------------
# Accuracy: 0.719512195122
# Most Informative Features
#         contains(towing) = True           60000- : 50000- =     17.5 : 1.0
#            contains(big) = True           60000- : 50000- =     17.5 : 1.0
#           contains(Have) = True           60000- : 50000- =     17.5 : 1.0
#        contains(machine) = True           60000- : 50000- =     17.5 : 1.0
#          contains(seems) = True           60000- : 50000- =     17.5 : 1.0
#           contains(high) = True           60000- : 50000- =     14.7 : 1.0
#          contains(until) = True           60000- : 50000- =     10.5 : 1.0
#            contains(set) = True           60000- : 50000- =     10.5 : 1.0
#          contains(board) = True           60000- : 50000- =     10.5 : 1.0
#      contains(Avalanche) = True           60000- : 50000- =     10.5 : 1.0
# ---------------------------------------------------feeding GMC Sierra-1500 2014 updateing-------------------------------------------
# Accuracy: 0.756097560976
# Most Informative Features
#           contains(snow) = True           60000- : 50000- =     23.0 : 1.0
#            contains(big) = True           60000- : 50000- =     23.0 : 1.0
#      contains(corrosion) = True           10000- : 50000- =     23.0 : 1.0
#         contains(towing) = True           60000- : 50000- =     23.0 : 1.0
#        contains(machine) = True           60000- : 50000- =     23.0 : 1.0
#       contains(actually) = True           40000- : 50000- =     18.2 : 1.0
#     contains(underneath) = True           10000- : 50000- =     13.8 : 1.0
#        contains(truck.I) = True           60000- : 50000- =     13.8 : 1.0
#        contains(ordered) = True           60000- : 50000- =     13.8 : 1.0
#          contains(until) = True           60000- : 50000- =     13.8 : 1.0
# ---------------------------------------------------feeding Ford F-150 2014 updateing-------------------------------------------
# Accuracy: 0.756097560976
# Most Informative Features
#           contains(snow) = True           60000- : 50000- =     23.3 : 1.0
#            contains(big) = True           60000- : 50000- =     23.3 : 1.0
#         contains(towing) = True           60000- : 50000- =     23.3 : 1.0
#      contains(corrosion) = True           10000- : 50000- =     23.3 : 1.0
#        contains(machine) = True           60000- : 50000- =     23.3 : 1.0
#       contains(actually) = True           40000- : 50000- =     18.4 : 1.0
#      contains(concerned) = True           60000- : 50000- =     14.0 : 1.0
#     contains(vibrations) = True           60000- : 50000- =     14.0 : 1.0
#             contains(to) = False          60000- : 50000- =     14.0 : 1.0
#           contains(Have) = True           60000- : 50000- =     14.0 : 1.0
# ---------------------------------------------------feeding Toyota Tundra 2014 updateing-------------------------------------------
# Accuracy: 0.792682926829
# Most Informative Features
#      contains(corrosion) = True           10000- : 50000- =     26.7 : 1.0
#           contains(Good) = True           60000- : 50000- =     18.7 : 1.0
#     contains(underneath) = True           10000- : 50000- =     16.0 : 1.0
#         contains(stated) = True           10000- : 50000- =     16.0 : 1.0
#           contains(pass) = True           10000- : 50000- =     16.0 : 1.0
#             contains(15) = True           10000- : 50000- =     16.0 : 1.0
#         contains(unless) = True           10000- : 50000- =     16.0 : 1.0
#           contains(lack) = True           10000- : 50000- =     16.0 : 1.0
#          contains(metal) = True           10000- : 50000- =     16.0 : 1.0
#             contains(ok) = True           10000- : 50000- =     16.0 : 1.0
# ---------------------------------------------------feeding Nissan Titan 2014 updateing-------------------------------------------
# Accuracy: 0.80487804878
# Most Informative Features
#      contains(corrosion) = True           10000- : 50000- =     26.7 : 1.0
#           contains(Good) = True           60000- : 50000- =     17.0 : 1.0
#     contains(underneath) = True           10000- : 50000- =     16.0 : 1.0
#         contains(stated) = True           10000- : 50000- =     16.0 : 1.0
#           contains(pass) = True           10000- : 50000- =     16.0 : 1.0
#             contains(15) = True           10000- : 50000- =     16.0 : 1.0
#         contains(unless) = True           10000- : 50000- =     16.0 : 1.0
#           contains(lack) = True           10000- : 50000- =     16.0 : 1.0
#          contains(metal) = True           10000- : 50000- =     16.0 : 1.0
#             contains(ok) = True           10000- : 50000- =     16.0 : 1.0
# ---------------------------------------------------feeding Chevrolet Silverado-1500 2013 updateing-------------------------------------------
# Accuracy: 0.80487804878
# Most Informative Features
#      contains(corrosion) = True           10000- : 50000- =     27.3 : 1.0
#       contains(powerful) = True           60000- : 50000- =     22.4 : 1.0
#           contains(Good) = True           60000- : 50000- =     17.4 : 1.0
#     contains(underneath) = True           10000- : 50000- =     16.4 : 1.0
#         contains(stated) = True           10000- : 50000- =     16.4 : 1.0
#           contains(pass) = True           10000- : 50000- =     16.4 : 1.0
#            contains(4.3) = True           10000- : 50000- =     16.4 : 1.0
#             contains(15) = True           10000- : 50000- =     16.4 : 1.0
#         contains(unless) = True           10000- : 50000- =     16.4 : 1.0
#           contains(lack) = True           10000- : 50000- =     16.4 : 1.0
# ---------------------------------------------------feeding Ram 1500 2013 updateing-------------------------------------------
# Accuracy: 0.829268292683
# Most Informative Features
#      contains(corrosion) = True           10000- : 50000- =     29.3 : 1.0
#     contains(underneath) = True           10000- : 50000- =     17.6 : 1.0
#         contains(stated) = True           10000- : 50000- =     17.6 : 1.0
#           contains(pass) = True           10000- : 50000- =     17.6 : 1.0
#            contains(4.3) = True           10000- : 50000- =     17.6 : 1.0
#         contains(unless) = True           10000- : 50000- =     17.6 : 1.0
#           contains(lack) = True           10000- : 50000- =     17.6 : 1.0
#          contains(metal) = True           10000- : 50000- =     17.6 : 1.0
#             contains(ok) = True           10000- : 50000- =     17.6 : 1.0
#        contains(rusting) = True           10000- : 50000- =     17.6 : 1.0
# ---------------------------------------------------feeding Ford F-150 2013 updateing-------------------------------------------
# Accuracy: 0.841463414634
# Most Informative Features
#      contains(corrosion) = True           10000- : 50000- =     19.0 : 1.0
#         contains(stated) = True           10000- : 50000- =     19.0 : 1.0
#           contains(pass) = True           10000- : 50000- =     19.0 : 1.0
#            contains(4.3) = True           10000- : 50000- =     19.0 : 1.0
#         contains(unless) = True           10000- : 50000- =     19.0 : 1.0
#           contains(lack) = True           10000- : 50000- =     19.0 : 1.0
#          contains(metal) = True           10000- : 50000- =     19.0 : 1.0
#         contains(myself) = True           10000- : 50000- =     19.0 : 1.0
#             contains(ok) = True           10000- : 50000- =     19.0 : 1.0
#            contains(11k) = True           10000- : 50000- =     19.0 : 1.0
# ---------------------------------------------------feeding Nissan Titan 2013 updateing-------------------------------------------
# Accuracy: 0.841463414634
# Most Informative Features
#      contains(corrosion) = True           10000- : 50000- =     19.0 : 1.0
#         contains(stated) = True           10000- : 50000- =     19.0 : 1.0
#           contains(pass) = True           10000- : 50000- =     19.0 : 1.0
#            contains(4.3) = True           10000- : 50000- =     19.0 : 1.0
#         contains(unless) = True           10000- : 50000- =     19.0 : 1.0
#           contains(lack) = True           10000- : 50000- =     19.0 : 1.0
#          contains(metal) = True           10000- : 50000- =     19.0 : 1.0
#         contains(myself) = True           10000- : 50000- =     19.0 : 1.0
#             contains(ok) = True           10000- : 50000- =     19.0 : 1.0
#            contains(11k) = True           10000- : 50000- =     19.0 : 1.0
#
# Running time is 353.486587048 seconds

# %%
from textblob.classifiers import NaiveBayesClassifier
from textblob import TextBlob
from collections import Counter
import math
import glob
import re
import time

start_time = time.time()
filename = "compact_suv"

def read_automobiles(filename):
    """ Read a list of automobiles.
    Args:
      filename: The name of the text file containing automobiles make model year.
    Returns:
      A list of automobile make model year
    """
    automobiles = []
    with open(filename) as f:
        lines = f.read().splitlines()
        for item in lines:
            automobiles.append(item)  
    return automobiles

autos = read_automobiles(filename+'.txt')
test = []
train = []
print "-------------------------------establishing initial training model--------------------------------"

for auto in autos:
    filelist = []
    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        # label the data with the TCO range, according to price ranges from edmunds.com
                        if float(line.split()[4]) >= 0 and float(line.split()[4])<15000:
                            price = "0-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<25000:
                            price = "15000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<35000:
                            price = "25000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<45000:
                            price = "35000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<55000:
                            price = "45000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<85000:
                            price = "55000-85000"
                        if float(line.split()[4]) >= 85000:
                            price = ">85000"
                            
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        if len(reviews)!=0:
                            for i in range(0,1):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))


training_percent = 0.8


for auto in autos:
    print "-------------------------------gethering test sample from "+auto+"--------------------------------"
    filelist = []

    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                        # label the data with the TCO range, according to price ranges from edmunds.com
                        if float(line.split()[4]) >= 0 and float(line.split()[4])<15000:
                            price = "0-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<25000:
                            price = "15000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<35000:
                            price = "25000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<45000:
                            price = "35000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<55000:
                            price = "45000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<85000:
                            price = "55000-85000"
                        if float(line.split()[4]) >= 85000:
                            price = ">85000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)

                        train_set = int(math.floor(len(reviews)*training_percent))
                    
                        for i in range(train_set,len(reviews)):
                            if (reviews[i].replace("\n","").decode('UTF-8'),price) not in train:
                                test.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
cl = NaiveBayesClassifier(train)
cl.show_informative_features(10)
print("Initial Accuracy: {0}".format(cl.accuracy(test)))
                            
for auto in autos:
    filelist = []
    train = []
    train_percent = 0.8
    filelist = glob.glob(filename + "_review/"+auto+"/*.txt")
    tcofile = glob.glob(filename + "_TCO/" + filename + "_TCO.txt")
    for fil in filelist:
        with open(tcofile[0],'r') as file2:
            with open(fil,'r') as file1:
                price = 0
                for line in file2:
                    if line.split()[3] == fil.split("/")[2][:9]:
                       # label the data with the TCO range, according to price ranges from edmunds.com
                        if float(line.split()[4]) >= 0 and float(line.split()[4])<15000:
                            price = "0-15000"
                        if float(line.split()[4]) >= 15000 and float(line.split()[4])<25000:
                            price = "15000-25000"
                        if float(line.split()[4]) >= 25000 and float(line.split()[4])<35000:
                            price = "25000-35000"
                        if float(line.split()[4]) >= 35000 and float(line.split()[4])<45000:
                            price = "35000-45000"
                        if float(line.split()[4]) >= 45000 and float(line.split()[4])<55000:
                            price = "45000-55000"
                        if float(line.split()[4]) >= 55000 and float(line.split()[4])<85000:
                            price = "55000-85000"
                        if float(line.split()[4]) >= 85000:
                            price = ">85000"
                        reviews = file1.read().split('\n------------------------------------------------------------------------------------------\n')
                        reviews = filter(None,reviews)
                        train_set = int(math.floor(len(reviews)*training_percent))
                        if train_set is 0:
                            for i in range(0,len(reviews)):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
                        else:
                            for i in range(0,train_set):
                                train.append((reviews[i].replace("\n","").decode('UTF-8'),
                                  price))
    print "---------------------------------------------------feeding "+auto+" updateing-------------------------------------------"                      
    phase_time = time.time()
    cl.update(train)
    # Compute accuracy
    print("Accuracy: {0}".format(cl.accuracy(test)))
 
    # Show 5 most informative features
    cl.show_informative_features(10)
    print "\n Feeding phase running time is %s second"%(time.time()-phase_time)
    
print "\nRunning time is %s seconds"%(time.time()-start_time)
# Out:
# -------------------------------establishing initial training model--------------------------------
# -------------------------------gethering test sample from honda cr-v 2013--------------------------------
# -------------------------------gethering test sample from buick encore 2013--------------------------------
# -------------------------------gethering test sample from gmc terrain 2013--------------------------------
# -------------------------------gethering test sample from nissan rogue 2013--------------------------------
# -------------------------------gethering test sample from ford escape 2013--------------------------------
# -------------------------------gethering test sample from mazda cx-5 2013--------------------------------
# -------------------------------gethering test sample from subaru forester 2013--------------------------------
# -------------------------------gethering test sample from chevrolet equinox 2013--------------------------------
# -------------------------------gethering test sample from jeep cherokee 2013--------------------------------
# -------------------------------gethering test sample from kia sportage 2013--------------------------------
# -------------------------------gethering test sample from dodge journey 2013--------------------------------
# -------------------------------gethering test sample from volkswagen tiguan 2013--------------------------------
# -------------------------------gethering test sample from hyundai tucson 2013--------------------------------
# -------------------------------gethering test sample from mini cooper-countryman 2013--------------------------------
# -------------------------------gethering test sample from nissan juke 2013--------------------------------
# -------------------------------gethering test sample from jeep wrangler 2013--------------------------------
# -------------------------------gethering test sample from toyota rav4 2013--------------------------------
# -------------------------------gethering test sample from mitsubishi outlander-sport 2013--------------------------------
# -------------------------------gethering test sample from jeep compass 2013--------------------------------
# -------------------------------gethering test sample from jeep patriot 2013--------------------------------
# -------------------------------gethering test sample from honda cr-v 2014--------------------------------
# -------------------------------gethering test sample from buick encore 2014--------------------------------
# -------------------------------gethering test sample from gmc terrain 2014--------------------------------
# -------------------------------gethering test sample from nissan rogue 2014--------------------------------
# -------------------------------gethering test sample from ford escape 2014--------------------------------
# -------------------------------gethering test sample from mazda cx-5 2014--------------------------------
# -------------------------------gethering test sample from subaru forester 2014--------------------------------
# -------------------------------gethering test sample from chevrolet equinox 2014--------------------------------
# -------------------------------gethering test sample from jeep cherokee 2014--------------------------------
# -------------------------------gethering test sample from kia sportage 2014--------------------------------
# -------------------------------gethering test sample from dodge journey 2014--------------------------------
# -------------------------------gethering test sample from volkswagen tiguan 2014--------------------------------
# -------------------------------gethering test sample from hyundai tucson 2014--------------------------------
# -------------------------------gethering test sample from mini cooper-countryman 2014--------------------------------
# -------------------------------gethering test sample from nissan juke 2014--------------------------------
# -------------------------------gethering test sample from jeep wrangler 2014--------------------------------
# -------------------------------gethering test sample from toyota rav4 2014--------------------------------
# -------------------------------gethering test sample from mitsubishi outlander-sport 2014--------------------------------
# -------------------------------gethering test sample from jeep compass 2014--------------------------------
# -------------------------------gethering test sample from jeep patriot 2014--------------------------------
# Most Informative Features
#           contains(shop) = True           0-1500 : 35000- =     49.5 : 1.0
#           contains(kept) = True           0-1500 : 35000- =     49.5 : 1.0
#           contains(died) = True           0-1500 : 35000- =     49.5 : 1.0
#          contains(brand) = True           0-1500 : 35000- =     49.5 : 1.0
#           contains(That) = True           0-1500 : 35000- =     49.5 : 1.0
#          contains(wrong) = True           0-1500 : 35000- =     49.5 : 1.0
#         contains(Tiguan) = True           55000- : 35000- =     41.2 : 1.0
#           contains(five) = True           0-1500 : 45000- =     40.5 : 1.0
#        contains(changed) = True           0-1500 : 45000- =     40.5 : 1.0
#       contains(thinking) = True           0-1500 : 45000- =     40.5 : 1.0
# Initial Accuracy: 0.533333333333
# ---------------------------------------------------feeding honda cr-v 2013 updateing-------------------------------------------
# Accuracy: 0.587878787879
# Most Informative Features
#           contains(five) = True           0-1500 : 35000- =     67.0 : 1.0
#           contains(That) = True           0-1500 : 35000- =     67.0 : 1.0
#         contains(figure) = True           0-1500 : 35000- =     67.0 : 1.0
#         contains(Tiguan) = True           55000- : 35000- =     55.8 : 1.0
#        contains(changed) = True           0-1500 : 45000- =     40.5 : 1.0
#           contains(shop) = True           0-1500 : 45000- =     40.5 : 1.0
#       contains(thinking) = True           0-1500 : 45000- =     40.5 : 1.0
#           contains(kept) = True           0-1500 : 45000- =     40.5 : 1.0
#          contains(heard) = True           0-1500 : 45000- =     40.5 : 1.0
#           contains(died) = True           0-1500 : 35000- =     40.2 : 1.0
#
#  Feeding phase running time is 140.490180016 second
# ---------------------------------------------------feeding buick encore 2013 updateing-------------------------------------------
# Accuracy: 0.6
# Most Informative Features
#           contains(five) = True           0-1500 : 35000- =     72.0 : 1.0
#           contains(That) = True           0-1500 : 35000- =     72.0 : 1.0
#          contains(heard) = True           0-1500 : 35000- =     72.0 : 1.0
#         contains(figure) = True           0-1500 : 35000- =     72.0 : 1.0
#         contains(Tiguan) = True           55000- : 35000- =     60.0 : 1.0
#           contains(kept) = True           0-1500 : 35000- =     43.2 : 1.0
#           contains(died) = True           0-1500 : 35000- =     43.2 : 1.0
#        contains(excited) = True           0-1500 : 35000- =     43.2 : 1.0
#          contains(brand) = True           0-1500 : 35000- =     43.2 : 1.0
#       contains(customer) = True           0-1500 : 35000- =     43.2 : 1.0
#
#  Feeding phase running time is 147.982343912 second
# ---------------------------------------------------feeding gmc terrain 2013 updateing-------------------------------------------
# Accuracy: 0.593939393939
# Most Informative Features
#           contains(five) = True           0-1500 : 35000- =     72.5 : 1.0
#           contains(That) = True           0-1500 : 35000- =     72.5 : 1.0
#          contains(heard) = True           0-1500 : 35000- =     72.5 : 1.0
#         contains(figure) = True           0-1500 : 35000- =     72.5 : 1.0
#         contains(Tiguan) = True           55000- : 35000- =     60.4 : 1.0
#        contains(changed) = True           0-1500 : 45000- =     45.0 : 1.0
#           contains(shop) = True           0-1500 : 45000- =     45.0 : 1.0
#       contains(thinking) = True           0-1500 : 45000- =     45.0 : 1.0
#           contains(kept) = True           0-1500 : 45000- =     45.0 : 1.0
#           contains(died) = True           0-1500 : 35000- =     43.5 : 1.0
#
#  Feeding phase running time is 152.832879066 second
# ---------------------------------------------------feeding nissan rogue 2013 updateing-------------------------------------------
# Accuracy: 0.569696969697
# Most Informative Features
#           contains(five) = True           0-1500 : 35000- =     74.0 : 1.0
